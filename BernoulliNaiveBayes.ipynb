# %%
# imports
from sklearn.naive_bayes import BernoulliNB
import functions
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import pandas as pd

# %%
# get data
X, y = functions.get_data()

# %%
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10)

# %%
# Create GaussianNB classifier
bnb = BernoulliNB()

# %%
# Fit the classifier to the data
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred = bnb.predict(X_test)

# %%
# calculate F1 score
f1 = f1_score(y_test, y_pred, average='weighted')

# %%
"F1 score is = {0}".format(f1)
# Out:
# 'F1 score is = 0.7290512586583276'

# %%
# write result to file
f = open("results/files/bnb_results.txt", "w+")
f.write("Final F1 score = {0} \n".format(f1))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred, columns=["y_pred"])

result['y_test'] = y_test["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("results/datasets/bnb_y_pred.csv")

result.head(20)
# Out:
#     y_pred  y_test  Current Loan Amount      Term  Credit Score  \
# 0        1       1            -0.400470  0.639329      0.091538
# 1        1       1            -0.402311  0.639329      0.161793
# 2        1       1             2.530987  0.639329      0.056410
# 3        1       1            -0.398169  0.639329     -0.681266
# 4        1       0            -0.385431 -1.564141     -2.859167
# 5        1       1            -0.391377  0.639329      1.039979
# 6        1       1            -0.401110  0.639329      0.899469
# 7        1       1             2.530987  0.639329      0.969724
# 8        1       1             2.530987  0.639329      0.934597
# 9        1       1            -0.391722  0.639329      0.372557
# 10       1       1            -0.395846 -1.564141      0.302303
# 11       1       1            -0.385182 -1.564141     -3.069932
# 12       1       1            -0.381830  0.639329     -1.348687
# 13       1       1            -0.394473  0.639329     -0.505629
# 14       1       1             2.530987  0.639329      0.688704
# 15       1       0            -0.398018  0.639329      0.758959
# 16       1       1            -0.395529  0.639329     -0.329991
# 17       1       1            -0.382243  0.639329      0.337430
# 18       1       1            -0.391612 -1.564141      0.021283
# 19       1       1            -0.399307  0.639329      0.161793
#
#     Annual Income  Years in current job  Monthly Debt  \
# 0       -0.747735              0.230938     -0.149150
# 1       -1.206717             -1.430694     -1.091931
# 2       -0.063130             -0.322939      0.033678
# 3       -0.552426             -0.599878     -0.854979
# 4        0.221173              1.061754      0.593562
# 5        0.395609             -1.707632      0.151266
# 6       -1.052728             -1.153755     -0.798297
# 7       -0.395453              1.061754      0.487938
# 8       -0.453828             -0.322939     -1.219301
# 9        0.264036             -0.322939      0.859388
# 10       0.217925              1.061754      0.820543
# 11       0.043652              1.061754      0.460303
# 12       1.370791             -0.876816      4.461844
# 13      -0.529624              0.230938      0.242649
# 14       1.282914              1.061754      0.665051
# 15      -0.366945             -0.876816      0.052221
# 16      -0.274743              1.061754      0.577892
# 17       2.410095              1.061754     -1.054436
# 18       2.081285              1.061754      0.402584
# 19      -0.848851             -1.153755     -0.572321
#
#     Years of Credit History  Months since last delinquent  ...  \
# 0                  2.033864                      0.599948  ...
# 1                 -0.490622                     -0.814524  ...
# 2                 -1.046610                      1.284370  ...
# 3                 -0.160034                      1.375627  ...
# 4                  0.516167                     -0.632012  ...
# 5                 -0.355382                     -1.270806  ...
# 6                 -0.129981                     -0.266987  ...
# 7                  0.185580                     -0.860152  ...
# 8                 -1.136770                     -0.540755  ...
# 9                  0.200606                      1.010601  ...
# 10                -0.340355                     -0.130102  ...
# 11                -0.069874                      0.736833  ...
# 12                 0.215633                     -1.362062  ...
# 13                -0.235168                     -0.997037  ...
# 14                 1.643170                      1.466883  ...
# 15                -1.422278                      1.193114  ...
# 16                 0.546221                     -0.038846  ...
# 17                -0.580782                      2.060049  ...
# 18                 0.185580                      0.006782  ...
# 19                -0.205115                     -1.225178  ...
#
#     Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 0               -0.111088      -0.180563            -0.077776
# 1               -0.111088      -0.180563            -0.077776
# 2               -0.111088      -0.180563            -0.077776
# 3               -0.111088      -0.180563            -0.077776
# 4               -0.111088      -0.180563            -0.077776
# 5               -0.111088      -0.180563            -0.077776
# 6               -0.111088       5.538246            -0.077776
# 7               -0.111088      -0.180563            -0.077776
# 8               -0.111088      -0.180563            -0.077776
# 9               -0.111088      -0.180563            -0.077776
# 10              -0.111088      -0.180563            -0.077776
# 11              -0.111088      -0.180563            -0.077776
# 12              -0.111088      -0.180563            -0.077776
# 13               9.001877      -0.180563            -0.077776
# 14              -0.111088      -0.180563            -0.077776
# 15              -0.111088      -0.180563            -0.077776
# 16              -0.111088      -0.180563            -0.077776
# 17              -0.111088      -0.180563            -0.077776
# 18              -0.111088      -0.180563            -0.077776
# 19              -0.111088      -0.180563            -0.077776
#
#     Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 0                -0.056524       -0.038889       3.840193
# 1                -0.056524       -0.038889      -0.260404
# 2                -0.056524       -0.038889      -0.260404
# 3                -0.056524       -0.038889      -0.260404
# 4                -0.056524       -0.038889      -0.260404
# 5                -0.056524       -0.038889      -0.260404
# 6                -0.056524       -0.038889      -0.260404
# 7                -0.056524       -0.038889      -0.260404
# 8                -0.056524       -0.038889      -0.260404
# 9                -0.056524       -0.038889      -0.260404
# 10               -0.056524       -0.038889      -0.260404
# 11               -0.056524       -0.038889      -0.260404
# 12               -0.056524       -0.038889      -0.260404
# 13               -0.056524       -0.038889      -0.260404
# 14               -0.056524       -0.038889      -0.260404
# 15               -0.056524       -0.038889      -0.260404
# 16               -0.056524       -0.038889      -0.260404
# 17               -0.056524       -0.038889      -0.260404
# 18               -0.056524       -0.038889      -0.260404
# 19               -0.056524       -0.038889      -0.260404
#
#     Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 0                   -0.01048               -0.055289          -0.03357
# 1                   -0.01048               -0.055289          -0.03357
# 2                   -0.01048               -0.055289          -0.03357
# 3                   -0.01048               -0.055289          -0.03357
# 4                   -0.01048               -0.055289          -0.03357
# 5                   -0.01048               -0.055289          -0.03357
# 6                   -0.01048               -0.055289          -0.03357
# 7                   -0.01048               -0.055289          -0.03357
# 8                   -0.01048               -0.055289          -0.03357
# 9                   -0.01048               -0.055289          -0.03357
# 10                  -0.01048               -0.055289          -0.03357
# 11                  -0.01048               -0.055289          -0.03357
# 12                  -0.01048               -0.055289          -0.03357
# 13                  -0.01048               -0.055289          -0.03357
# 14                  -0.01048               -0.055289          -0.03357
# 15                  -0.01048               -0.055289          -0.03357
# 16                  -0.01048               -0.055289          -0.03357
# 17                  -0.01048               -0.055289          -0.03357
# 18                  -0.01048               -0.055289          -0.03357
# 19                  -0.01048               -0.055289          -0.03357
#
#     Purpose_wedding
# 0          -0.03274
# 1          -0.03274
# 2          -0.03274
# 3          -0.03274
# 4          -0.03274
# 5          -0.03274
# 6          -0.03274
# 7          -0.03274
# 8          -0.03274
# 9          -0.03274
# 10         -0.03274
# 11         -0.03274
# 12         -0.03274
# 13         -0.03274
# 14         -0.03274
# 15         -0.03274
# 16         -0.03274
# 17         -0.03274
# 18         -0.03274
# 19         -0.03274
#
# [20 rows x 38 columns]
