# %%
# imports
from sklearn.naive_bayes import BernoulliNB
import importlib.util
spec = importlib.util.spec_from_file_location("module.name", "../functions.py")
functions = importlib.util.module_from_spec(spec)
spec.loader.exec_module(functions)
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import pandas as pd

# %%
# get data
X, y = functions.get_data()
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
# Create BernoulliNB classifier
bnb = BernoulliNB()
# Fit the classifier to the data
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred_basic = bnb.predict(X_test)

# %%
# calculate F1 score
f1_basic = f1_score(y_test, y_pred_basic)
"F1 score is = {0}".format(f1_basic)
# Out:
# 'F1 score is = 0.13706102966246167'

# %%
# write result to file
f = open("../results/files/bnb_results.txt", "w+")
f.write("Basic BNB: F1 score = {0} \n".format(f1_basic))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_basic, columns=["y_pred"])

result['y_test'] = y_test["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("../results/datasets/bnb_prediction_basic.csv")

result.head(20)
# Out:
#     y_pred  y_test  Current Loan Amount      Term  Credit Score  \
# 0      0.0     0.0            -0.394667 -1.564141      0.056410
# 1      0.0     0.0            -0.397812  0.639329     -0.365119
# 2      0.0     0.0            -0.399256  0.639329      1.039979
# 3      0.0     0.0            -0.394479 -1.564141      0.688704
# 4      0.0     0.0            -0.384398 -1.564141     -0.786648
# 5      0.0     0.0            -0.392940  0.639329      0.267175
# 6      0.0     0.0             2.530987  0.639329      0.407685
# 7      0.0     0.0            -0.398426  0.639329      0.372557
# 8      0.0     0.0            -0.396693  0.639329     -0.435374
# 9      1.0     0.0            -0.390100 -1.564141     -1.032540
# 10     0.0     0.0             2.530987  0.639329      0.021283
# 11     0.0     0.0            -0.388797  0.639329      0.969724
# 12     0.0     0.0            -0.402783  0.639329      0.477940
# 13     0.0     0.0            -0.396113  0.639329      0.126665
# 14     0.0     0.0            -0.400109  0.639329      0.021283
# 15     0.0     0.0             2.530987  0.639329      0.477940
# 16     0.0     1.0            -0.381909 -1.564141      0.196920
# 17     0.0     0.0            -0.397865  0.639329      0.899469
# 18     0.0     0.0            -0.395744  0.639329      0.794087
# 19     0.0     0.0            -0.394816  0.639329      0.126665
#
#     Annual Income  Years in current job  Monthly Debt  \
# 0       -0.274925              1.061754      0.527710
# 1       -0.180083             -0.599878     -1.221986
# 2       -0.889907             -0.876816     -1.513202
# 3        0.259021             -1.707632     -0.487423
# 4       -0.252631             -0.876816     -0.874324
# 5       -0.806496             -1.153755     -0.208926
# 6        0.316158              1.061754      0.577656
# 7       -0.153484              1.061754     -1.282201
# 8        2.256472             -0.599878      0.429481
# 9       -0.667309             -0.046001      0.247407
# 10      -0.862841             -0.322939     -0.705391
# 11       0.678876              0.230938      0.649004
# 12       0.770734              1.061754      2.516979
# 13      -0.196449              1.061754     -0.886806
# 14       0.160077              1.061754      0.230873
# 15      -0.435635              1.061754     -0.857256
# 16       1.259604              0.230938      1.265476
# 17      -0.501787              1.061754     -0.393261
# 18       0.037317              1.061754     -0.074427
# 19      -0.363656             -0.322939     -0.152306
#
#     Years of Credit History  Months since last delinquent  ...  \
# 0                  0.501141                      0.417436  ...
# 1                 -0.084901                      0.189295  ...
# 2                 -1.196877                      0.508692  ...
# 3                 -0.911370                      0.828089  ...
# 4                 -0.340355                     -0.997037  ...
# 5                 -0.280248                     -0.221358  ...
# 6                  0.170553                     -0.860152  ...
# 7                 -0.460568                     -1.270806  ...
# 8                 -0.370408                     -0.403871  ...
# 9                 -0.956450                      0.736833  ...
# 10                -1.602598                     -0.905781  ...
# 11                 0.681461                      1.101858  ...
# 12                 1.943704                     -1.362062  ...
# 13                -0.685969                     -0.358243  ...
# 14                -0.460568                     -1.133921  ...
# 15                 0.080393                      1.193114  ...
# 16                 0.215633                      0.554320  ...
# 17                 0.215633                      2.060049  ...
# 18                 1.793437                      0.234923  ...
# 19                -1.151797                      0.463064  ...
#
#     Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 0               -0.111088      -0.180563            -0.077776
# 1               -0.111088      -0.180563            -0.077776
# 2               -0.111088      -0.180563            -0.077776
# 3               -0.111088      -0.180563            -0.077776
# 4               -0.111088      -0.180563            -0.077776
# 5               -0.111088      -0.180563            -0.077776
# 6               -0.111088      -0.180563            -0.077776
# 7               -0.111088      -0.180563            -0.077776
# 8               -0.111088      -0.180563            -0.077776
# 9               -0.111088      -0.180563            -0.077776
# 10              -0.111088      -0.180563            -0.077776
# 11              -0.111088      -0.180563            -0.077776
# 12              -0.111088      -0.180563            -0.077776
# 13              -0.111088       5.538246            -0.077776
# 14              -0.111088      -0.180563            12.857491
# 15              -0.111088      -0.180563            -0.077776
# 16              -0.111088      -0.180563            -0.077776
# 17              -0.111088      -0.180563            -0.077776
# 18              -0.111088      -0.180563            -0.077776
# 19              -0.111088      -0.180563            -0.077776
#
#     Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 0                -0.056524       -0.038889      -0.260404
# 1                -0.056524       -0.038889      -0.260404
# 2                -0.056524       -0.038889      -0.260404
# 3                -0.056524       -0.038889      -0.260404
# 4                -0.056524       -0.038889      -0.260404
# 5                -0.056524       -0.038889      -0.260404
# 6                -0.056524       -0.038889      -0.260404
# 7                -0.056524       -0.038889      -0.260404
# 8                -0.056524       -0.038889      -0.260404
# 9                -0.056524       -0.038889      -0.260404
# 10               -0.056524       -0.038889      -0.260404
# 11               -0.056524       -0.038889      -0.260404
# 12               -0.056524       -0.038889      -0.260404
# 13               -0.056524       -0.038889      -0.260404
# 14               -0.056524       -0.038889      -0.260404
# 15               -0.056524       -0.038889      -0.260404
# 16               -0.056524       -0.038889      -0.260404
# 17               -0.056524       -0.038889      -0.260404
# 18               -0.056524       -0.038889      -0.260404
# 19               -0.056524       -0.038889      -0.260404
#
#     Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 0                   -0.01048               -0.055289          -0.03357
# 1                   -0.01048               -0.055289          -0.03357
# 2                   -0.01048               -0.055289          -0.03357
# 3                   -0.01048               -0.055289          -0.03357
# 4                   -0.01048               -0.055289          -0.03357
# 5                   -0.01048               -0.055289          -0.03357
# 6                   -0.01048               -0.055289          -0.03357
# 7                   -0.01048               -0.055289          -0.03357
# 8                   -0.01048               -0.055289          -0.03357
# 9                   -0.01048               -0.055289          -0.03357
# 10                  -0.01048               -0.055289          -0.03357
# 11                  -0.01048               -0.055289          -0.03357
# 12                  -0.01048               -0.055289          -0.03357
# 13                  -0.01048               -0.055289          -0.03357
# 14                  -0.01048               -0.055289          -0.03357
# 15                  -0.01048               -0.055289          -0.03357
# 16                  -0.01048               -0.055289          -0.03357
# 17                  -0.01048               -0.055289          -0.03357
# 18                  -0.01048               -0.055289          -0.03357
# 19                  -0.01048               -0.055289          -0.03357
#
#     Purpose_wedding
# 0          -0.03274
# 1          -0.03274
# 2          -0.03274
# 3          -0.03274
# 4          -0.03274
# 5          -0.03274
# 6          -0.03274
# 7          -0.03274
# 8          -0.03274
# 9          -0.03274
# 10         -0.03274
# 11         -0.03274
# 12         -0.03274
# 13         -0.03274
# 14         -0.03274
# 15         -0.03274
# 16         -0.03274
# 17         -0.03274
# 18         -0.03274
# 19         -0.03274
#
# [20 rows x 38 columns]

# %%
# get data
X, y = functions.get_data(type="__removeoutliers")
# split dataset into train and test data
X_train, X_test, y_train, y_test_outliers = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
# Create BernoulliNB classifier
bnb = BernoulliNB()
# Fit the classifier to the data
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred_outliers = bnb.predict(X_test)

# %%
# calculate F1 score
f1_outliers = f1_score(y_test_outliers, y_pred_outliers)
"F1 score is = {0}".format(f1_outliers)
# Out:
# 'F1 score is = 0.13550135501355012'

# %%
# write result to file
f = open("../results/files/bnb_results.txt", "a")
f.write("Basic BNB without outliers: F1 score = {0} \n".format(f1_outliers))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_outliers, columns=["y_pred"])

result['y_test'] = y_test_outliers["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("../results/datasets/bnb_prediction_basic_removed_outliers.csv")

result.head(20)
# Out:
#     y_pred  y_test  Current Loan Amount      Term  Credit Score  \
# 0      0.0     1.0            -0.394113 -1.607808     -0.567288
# 1      0.0     0.0            -0.382631  0.621965     -0.531438
# 2      0.0     1.0            -0.396374  0.621965      0.185566
# 3      0.0     1.0            -0.392333  0.621965      0.221416
# 4      0.0     0.0            -0.396821  0.621965      0.400667
# 5      0.0     0.0            -0.396350  0.621965      1.010121
# 6      0.0     0.0            -0.396922  0.621965      0.723319
# 7      0.0     0.0            -0.388737  0.621965      0.293117
# 8      0.0     0.0            -0.392260 -1.607808      0.759169
# 9      0.0     1.0            -0.393592 -1.607808     -1.320142
# 10     0.0     0.0            -0.395605  0.621965      0.795020
# 11     0.0     0.0             2.542801  0.621965      0.508218
# 12     0.0     0.0            -0.397905  0.621965     -0.997490
# 13     0.0     0.0            -0.390274 -1.607808     -1.857895
# 14     0.0     1.0            -0.400089  0.621965      0.257267
# 15     0.0     1.0            -0.398781  0.621965      0.544068
# 16     0.0     0.0            -0.395499  0.621965      1.010121
# 17     0.0     0.0             2.542801  0.621965      0.830870
# 18     0.0     0.0            -0.390045  0.621965      1.261072
# 19     0.0     0.0             2.542801 -1.607808      0.293117
#
#     Annual Income  Years in current job  Monthly Debt  \
# 0        0.073933              1.072465     -1.128872
# 1        0.978727              1.072465      0.688797
# 2       -0.206339              0.795289     -0.309064
# 3       -0.671096              1.072465     -1.151383
# 4       -0.033980             -1.699297     -0.326412
# 5       -0.631371             -1.144945     -1.405344
# 6       -0.948417             -1.422121     -0.376552
# 7       -0.541701              1.072465      0.171164
# 8       -0.228612              1.072465      1.214596
# 9       -0.057621              1.072465      1.456709
# 10      -0.865692              0.518113      0.656512
# 11      -0.790560             -1.422121     -0.855173
# 12      -1.196232             -1.422121     -0.595394
# 13      -0.980046              1.072465     -0.586212
# 14      -1.652174             -1.144945     -0.770822
# 15      -0.002639             -1.144945      1.498958
# 16      -0.803837             -1.699297     -0.847747
# 17       1.148999             -1.144945     -0.362462
# 18      -0.767566             -1.699297     -0.523631
# 19      -0.740759              1.072465     -0.460162
#
#     Years of Credit History  Months since last delinquent  ...  \
# 0                  0.360483                     -1.198510  ...
# 1                 -0.410890                     -0.013890  ...
# 2                  0.730742                      0.487295  ...
# 3                  1.471260                      1.170729  ...
# 4                  0.838734                     -0.879574  ...
# 5                  0.237064                      0.669544  ...
# 6                 -0.457172                     -0.105015  ...
# 7                 -0.457172                      1.352979  ...
# 8                 -0.565164                      0.669544  ...
# 9                 -0.997133                     -1.289635  ...
# 10                -0.950851                      0.578419  ...
# 11                 1.008436                     -1.244073  ...
# 12                -0.472599                      0.669544  ...
# 13                -0.950851                      0.259483  ...
# 14                -1.567949                      0.396170  ...
# 15                 1.270703                      1.398541  ...
# 16                -0.565164                      0.122796  ...
# 17                -0.133195                     -0.241702  ...
# 18                 0.545613                      0.168359  ...
# 19                -0.472599                     -0.150577  ...
#
#     Purpose_Medical Bills  Purpose_Other  Purpose_Take a Trip  \
# 0                -0.11134      -0.183300            -0.079789
# 1                -0.11134      -0.183300            -0.079789
# 2                -0.11134      -0.183300            -0.079789
# 3                -0.11134      -0.183300            -0.079789
# 4                -0.11134      -0.183300            -0.079789
# 5                -0.11134      -0.183300            -0.079789
# 6                -0.11134      -0.183300            -0.079789
# 7                -0.11134      -0.183300            -0.079789
# 8                -0.11134      -0.183300            -0.079789
# 9                -0.11134      -0.183300            -0.079789
# 10               -0.11134      -0.183300            -0.079789
# 11               -0.11134      -0.183300            -0.079789
# 12               -0.11134       5.455548            -0.079789
# 13               -0.11134      -0.183300            -0.079789
# 14               -0.11134      -0.183300            -0.079789
# 15                8.98151      -0.183300            -0.079789
# 16               -0.11134      -0.183300            -0.079789
# 17               -0.11134      -0.183300            -0.079789
# 18               -0.11134      -0.183300            -0.079789
# 19               -0.11134      -0.183300            -0.079789
#
#     Purpose_major_purchase  Purpose_moving  Purpose_other  \
# 0                -0.058525       -0.037146      -0.263625
# 1                -0.058525       -0.037146       3.793272
# 2                -0.058525       -0.037146      -0.263625
# 3                -0.058525       -0.037146      -0.263625
# 4                -0.058525       -0.037146      -0.263625
# 5                -0.058525       -0.037146      -0.263625
# 6                -0.058525       -0.037146      -0.263625
# 7                -0.058525       -0.037146      -0.263625
# 8                -0.058525       -0.037146      -0.263625
# 9                -0.058525       -0.037146      -0.263625
# 10               -0.058525       -0.037146      -0.263625
# 11               -0.058525       -0.037146       3.793272
# 12               -0.058525       -0.037146      -0.263625
# 13               -0.058525       -0.037146      -0.263625
# 14               -0.058525       -0.037146      -0.263625
# 15               -0.058525       -0.037146      -0.263625
# 16               -0.058525       -0.037146      -0.263625
# 17               -0.058525       -0.037146      -0.263625
# 18               -0.058525       -0.037146      -0.263625
# 19               -0.058525       -0.037146      -0.263625
#
#     Purpose_renewable_energy  Purpose_small_business  Purpose_vacation  \
# 0                  -0.011193               -0.051662         -0.033596
# 1                  -0.011193               -0.051662         -0.033596
# 2                  -0.011193               -0.051662         -0.033596
# 3                  -0.011193               -0.051662         -0.033596
# 4                  -0.011193               -0.051662         -0.033596
# 5                  -0.011193               -0.051662         -0.033596
# 6                  -0.011193               -0.051662         -0.033596
# 7                  -0.011193               -0.051662         -0.033596
# 8                  -0.011193               -0.051662         -0.033596
# 9                  -0.011193               -0.051662         -0.033596
# 10                 -0.011193               -0.051662         -0.033596
# 11                 -0.011193               -0.051662         -0.033596
# 12                 -0.011193               -0.051662         -0.033596
# 13                 -0.011193               -0.051662         -0.033596
# 14                 -0.011193               -0.051662         -0.033596
# 15                 -0.011193               -0.051662         -0.033596
# 16                 -0.011193               -0.051662         -0.033596
# 17                 -0.011193               -0.051662         -0.033596
# 18                 -0.011193               -0.051662         -0.033596
# 19                 -0.011193               -0.051662         -0.033596
#
#     Purpose_wedding
# 0         -0.032648
# 1         -0.032648
# 2         -0.032648
# 3         -0.032648
# 4         -0.032648
# 5         -0.032648
# 6         -0.032648
# 7         -0.032648
# 8         -0.032648
# 9         -0.032648
# 10        -0.032648
# 11        -0.032648
# 12        -0.032648
# 13        -0.032648
# 14        -0.032648
# 15        -0.032648
# 16        -0.032648
# 17        -0.032648
# 18        -0.032648
# 19        -0.032648
#
# [20 rows x 38 columns]

# %%
# get data
X, y = functions.get_data(type="__PCA")
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred_PCA = bnb.predict(X_test)

# %%
# calculate F1 score
f1_PCA = f1_score(y_test, y_pred_PCA)
"F1 score is = {0}".format(f1_PCA)
# Out:
# 'F1 score is = 0.8794612794612795'

# %%
# write result to file
f = open("../results/files/bnb_results.txt", "a")
f.write("Basic BNB with PCA features: F1 score = {0} \n".format(f1_PCA))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_PCA, columns=["y_pred"])

result['y_test'] = y_test["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("../results/datasets/bnb_prediction_PCA_features.csv")

result.head(20)
# Out:
#     y_pred  y_test         0         1         2         3         4  \
# 0      0.0     0.0 -0.394669 -0.028743 -0.257270 -0.289530 -0.758346
# 1      0.0     0.0 -0.397813 -0.057037 -0.172509  0.052432  1.406923
# 2      0.0     0.0 -0.399265 -0.097745 -0.894736  0.375965  1.160763
# 3      0.0     0.0 -0.394477 -0.021281  0.241131  0.657245  0.580866
# 4      0.0     0.0 -0.384401 -0.007250 -0.273162  0.671431  0.703325
# 1  -0.092979 -0.109952  0.050968  0.022644  0.024899  0.061057
# 2  -0.014457 -0.027887 -0.074415 -0.124431 -0.043032  0.000129
# 3   0.008497  0.019301 -0.054198 -0.201127 -0.005035  0.069333
# 4  -0.577811 -0.660793 -0.241396 -0.074608 -0.119823  0.119431
# 5  -0.052825 -0.022478 -0.075731 -0.015372 -0.043908 -0.014156
# 6   0.049238 -0.065990 -0.055590  0.057247  0.016916 -0.029343
# 7  -0.558068 -0.636538 -0.270063 -0.033699 -0.164098  0.023064
# 8  -0.126551 -0.031899  0.105481  0.069157  0.019873  0.096250
# 9  -0.052315 -0.057815 -0.021426 -0.057958 -0.089168 -0.030953
# 10 -0.050984 -0.062488 -0.059299 -0.046506 -0.105881  0.023408
# 11  0.013204 -0.032450 -0.014355  0.005483  0.051379 -0.006709
# 12  0.022362  0.019321 -0.049802  0.126415  0.045365 -0.079661
# 13 -2.633949 -0.081642 -0.573604 -0.066180 -0.329405  0.075625
# 14  1.830239 -0.059617  1.285496  0.296179  7.300727  5.968778
# 15 -0.020271  4.200906  0.277310 -0.085962  0.000802 -0.049772
# 16 -0.016114  0.000973  0.050391 -0.016823  0.066703  0.058226
# 17  0.020554 -0.057560 -0.009354 -0.037434  0.027565 -0.035621
# 18  0.004059 -0.045088 -0.029275  0.017178  0.041581 -0.040758
# 19 -0.018519 -0.076365  0.012075  0.005103  0.023013  0.021117
#
# [20 rows x 28 columns]

# %%
# get data
X, y = functions.get_data(type="__FTs")
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred_FT = bnb.predict(X_test)

# %%
# calculate F1 score
f1_FT = f1_score(y_test, y_pred_FT)
"F1 score is = {0}".format(f1_FT)
# Out:
# 'F1 score is = 0.3770600965540203'

# %%
# write result to file
f = open("../results/files/bnb_results.txt", "a")
f.write("Basic BNB with FT features: F1 score = {0} \n".format(f1_FT))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_FT, columns=["y_pred"])

result['y_test'] = y_test["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("../results/datasets/bnb_prediction_FT_features.csv")

result.head(20)
# Out:
#     y_pred  y_test  Current Loan Amount  Current Loan Amount + Term  \
# 0      1.0     0.0            -0.394667                   -1.335361
# 1      1.0     0.0            -0.397812                    0.164647
# 2      1.0     0.0            -0.399256                    0.163663
# 3      1.0     0.0            -0.394479                   -1.335233
# 4      1.0     0.0            -0.384398                   -1.328361
# 5      1.0     0.0            -0.392940                    0.167968
# 6      0.0     0.0             2.530987                    2.161271
# 7      1.0     0.0            -0.398426                    0.164228
# 8      1.0     0.0            -0.396693                    0.165410
# 9      1.0     0.0            -0.390100                   -1.332247
# 10     0.0     0.0             2.530987                    2.161271
# 11     1.0     0.0            -0.388797                    0.170793
# 12     1.0     0.0            -0.402783                    0.161258
# 13     0.0     0.0            -0.396113                    0.165805
# 14     0.0     0.0            -0.400109                    0.163081
# 15     0.0     0.0             2.530987                    2.161271
# 16     1.0     1.0            -0.381909                   -1.326663
# 17     1.0     0.0            -0.397865                    0.164611
# 18     1.0     0.0            -0.395744                    0.166057
# 19     1.0     0.0            -0.394816                    0.166690
#
#     Current Loan Amount / Purpose_Other  \
# 0                              0.400739
# 1                              0.403938
# 2                              0.405406
# 3                              0.400549
# 4                              0.390297
# 5                              0.398983
# 6                             -2.574281
# 7                              0.404562
# 8                              0.402799
# 9                              0.396095
# 10                            -2.574281
# 11                             0.394771
# 12                             0.408992
# 13                            -0.013719
# 14                             0.406273
# 15                            -2.574281
# 16                             0.387766
# 17                             0.403992
# 18                             0.401835
# 19                             0.400891
#
#     Current Loan Amount / Purpose_Medical Bills  \
# 0                                      0.397562
# 1                                      0.400724
# 2                                      0.402175
# 3                                      0.397374
# 4                                      0.387238
# 5                                      0.395826
# 6                                     -2.543845
# 7                                      0.401342
# 8                                      0.399599
# 9                                      0.392970
# 10                                    -2.543845
# 11                                     0.391661
# 12                                     0.405722
# 13                                     0.399016
# 14                                     0.403033
# 15                                    -2.543845
# 16                                     0.384735
# 17                                     0.400778
# 18                                     0.398645
# 19                                     0.397712
#
#     Current Loan Amount / Purpose_Educational Expenses  \
# 0                                            0.394685
# 1                                            0.397833
# 2                                            0.399277
# 3                                            0.394497
# 4                                            0.384409
# 5                                            0.392957
# 6                                           -2.533190
# 7                                            0.398447
# 8                                            0.396712
# 9                                            0.390114
# 10                                          -2.533190
# 11                                           0.388811
# 12                                           0.402807
# 13                                           0.396132
# 14                                           0.400131
# 15                                          -2.533190
# 16                                           0.381917
# 17                                           0.397886
# 18                                           0.395763
# 19                                           0.394834
#
#     Current Loan Amount / Purpose_small_business  \
# 0                                       0.395503
# 1                                       0.398652
# 2                                       0.400097
# 3                                       0.395316
# 4                                       0.385224
# 5                                       0.393775
# 6                                      -2.533363
# 7                                       0.399267
# 8                                       0.397531
# 9                                       0.390931
# 10                                     -2.533363
# 11                                      0.389627
# 12                                      0.403628
# 13                                      0.396952
# 14                                      0.400951
# 15                                     -2.533363
# 16                                      0.382731
# 17                                      0.398705
# 18                                      0.396582
# 19                                      0.395653
#
#     Current Loan Amount / Purpose_renewable_energy  \
# 0                                         0.394714
# 1                                         0.397860
# 2                                         0.399303
# 3                                         0.394527
# 4                                         0.384446
# 5                                         0.392987
# 6                                        -2.530965
# 7                                         0.398474
# 8                                         0.396740
# 9                                         0.390147
# 10                                       -2.530965
# 11                                        0.388845
# 12                                        0.402830
# 13                                        0.396161
# 14                                        0.400156
# 15                                       -2.530965
# 16                                        0.381956
# 17                                        0.397913
# 18                                        0.395791
# 19                                        0.394863
#
#     Current Loan Amount / Purpose_wedding  ...  1 % Current Loan Amount  \
# 0                                0.394797  ...                -0.391666
# 1                                0.397945  ...                -0.414946
# 2                                0.399389  ...                -0.425628
# 3                                0.394610  ...                -0.390280
# 4                                0.384522  ...                -0.315669
# 5                                0.393069  ...                -0.378886
# 6                               -2.532860  ...                 2.529225
# 7                                0.398560  ...                -0.419491
# 8                                0.396825  ...                -0.406658
# 9                                0.390227  ...                -0.357866
# 10                              -2.532860  ...                 2.529225
# 11                               0.388924  ...                -0.348226
# 12                               0.402919  ...                -0.451732
# 13                               0.396245  ...                -0.402371
# 14                               0.400243  ...                -0.431941
# 15                              -2.532860  ...                 2.529225
# 16                               0.382031  ...                -0.297245
# 17                               0.397998  ...                -0.415338
# 18                               0.395875  ...                -0.399637
# 19                               0.394947  ...                -0.392770
#
#     1 / Current Loan Amount  0 - Current Loan Amount  \
# 0                 -0.397123                 0.394667
# 1                 -0.377102                 0.397812
# 2                 -0.368021                 0.399256
# 3                 -0.398325                 0.394479
# 4                 -0.464759                 0.384398
# 5                 -0.408250                 0.392940
# 6                  2.529647                -2.530987
# 7                 -0.373230                 0.398426
# 8                 -0.384193                 0.396693
# 9                 -0.426765                 0.390100
# 10                 2.529647                -2.530987
# 11                -0.435346                 0.388797
# 12                -0.346104                 0.402783
# 13                -0.387877                 0.396113
# 14                -0.362685                 0.400109
# 15                 2.529647                -2.530987
# 16                -0.481705                 0.381909
# 17                -0.376768                 0.397865
# 18                -0.390231                 0.395744
# 19                -0.396166                 0.394816
#
#     Current Loan Amount / Purpose_major_purchase  \
# 0                                       0.395148
# 1                                       0.398299
# 2                                       0.399745
# 3                                       0.394960
# 4                                       0.384860
# 5                                       0.393418
# 6                                      -2.536025
# 7                                       0.398915
# 8                                       0.397177
# 9                                       0.390572
# 10                                     -2.536025
# 11                                      0.389267
# 12                                      0.403279
# 13                                      0.396597
# 14                                      0.400600
# 15                                     -2.536025
# 16                                      0.382366
# 17                                      0.398352
# 18                                      0.396227
# 19                                      0.395297
#
#     Credit Score + Current Loan Amount  Current Loan Amount / Purpose_moving  \
# 0                            -0.225018                              0.394803
# 1                            -0.507524                              0.397952
# 2                             0.426228                              0.399397
# 3                             0.195727                              0.394616
# 4                            -0.779014                              0.384524
# 5                            -0.083662                              0.393075
# 6                             1.954890                             -2.533966
# 7                            -0.017209                              0.398567
# 8                            -0.553515                              0.396831
# 9                            -0.946381                              0.390232
# 10                            1.697844                             -2.533966
# 11                            0.386449                              0.388928
# 12                            0.049997                              0.402928
# 13                           -0.179245                              0.396251
# 14                           -0.252006                              0.400251
# 15                            2.001625                             -2.533966
# 16                           -0.123060                              0.382032
# 17                            0.333681                              0.398005
# 18                            0.264989                              0.395882
# 19                           -0.178382                              0.394953
#
#     Current Loan Amount / Purpose_Take a Trip  \
# 0                                    0.395778
# 1                                    0.398934
# 2                                    0.400382
# 3                                    0.395590
# 4                                    0.385476
# 5                                    0.394046
# 6                                   -2.539360
# 7                                    0.399550
# 8                                    0.397811
# 9                                    0.391196
# 10                                  -2.539360
# 11                                   0.389890
# 12                                   0.403921
# 13                                   0.397229
# 14                                  -0.002596
# 15                                  -2.539360
# 16                                   0.382979
# 17                                   0.398987
# 18                                   0.396859
# 19                                   0.395928
#
#     Current Loan Amount / Home Ownership_HaveMortgage  \
# 0                                            0.395048
# 1                                            0.398198
# 2                                            0.399644
# 3                                            0.394861
# 4                                            0.384765
# 5                                            0.393319
# 6                                           -2.534688
# 7                                            0.398813
# 8                                            0.397077
# 9                                            0.390475
# 10                                          -2.534688
# 11                                           0.389171
# 12                                           0.403176
# 13                                           0.396497
# 14                                           0.400498
# 15                                          -2.534688
# 16                                           0.382272
# 17                                           0.398251
# 18                                           0.396127
# 19                                           0.395198
#
#     Current Loan Amount / Purpose_Buy House  \
# 0                                  0.396305
# 1                                  0.399460
# 2                                  0.400908
# 3                                  0.396117
# 4                                  0.386003
# 5                                  0.394572
# 6                                 -2.538818
# 7                                  0.400077
# 8                                  0.398337
# 9                                  0.391723
# 10                                -2.538818
# 11                                 0.390416
# 12                                 0.404447
# 13                                 0.397756
# 14                                 0.401764
# 15                                -2.538818
# 16                                 0.383505
# 17                                 0.399514
# 18                                 0.397385
# 19                                 0.396454
#
#     Current Loan Amount / Purpose_Buy a Car
# 0                                  0.396804
# 1                                  0.399970
# 2                                  0.401422
# 3                                  0.396616
# 4                                  0.386470
# 5                                  0.395066
# 6                                 -2.547566
# 7                                  0.400588
# 8                                  0.398843
# 9                                  0.392208
# 10                                -2.547566
# 11                                 0.390897
# 12                                 0.404972
# 13                                 0.398260
# 14                                 0.402281
# 15                                -2.547566
# 16                                 0.383965
# 17                                 0.400023
# 18                                 0.397888
# 19                                 0.396954
#
# [20 rows x 22 columns]

# %%
# get data
X, y = functions.get_data(type="__polynomial")
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
# predict test values
y_pred_poly = bnb.predict(X_test)

# %%
# calculate F1 score
f1_poly = f1_score(y_test, y_pred_poly)
"F1 score is = {0}".format(f1_poly)
# Out:
# 'F1 score is = 0.3647163647163647'

# %%
# write result to file
f = open("../results/files/bnb_results.txt", "a")
f.write("Basic BNB with polynomial features: F1 score = {0} \n".format(f1_poly))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_poly, columns=["y_pred"])

result['y_test'] = y_test["Loan Status"].values

result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

result = pd.concat([result, X_test], axis=1)

result.to_csv("../results/datasets/bnb_prediction_polynomial_features.csv")

result.head(20)
# Out:
#     y_pred  y_test  Current Loan Amount      Term  Credit Score  \
# 0      0.0     0.0            -0.394667 -1.564141      0.056410
# 1      0.0     0.0            -0.397812  0.639329     -0.365119
# 2      1.0     0.0            -0.399256  0.639329      1.039979
# 3      0.0     0.0            -0.394479 -1.564141      0.688704
# 4      1.0     0.0            -0.384398 -1.564141     -0.786648
# 5      1.0     0.0            -0.392940  0.639329      0.267175
# 6      0.0     0.0             2.530987  0.639329      0.407685
# 7      0.0     0.0            -0.398426  0.639329      0.372557
# 8      0.0     0.0            -0.396693  0.639329     -0.435374
# 9      1.0     0.0            -0.390100 -1.564141     -1.032540
# 10     0.0     0.0             2.530987  0.639329      0.021283
# 11     0.0     0.0            -0.388797  0.639329      0.969724
# 12     0.0     0.0            -0.402783  0.639329      0.477940
# 13     0.0     0.0            -0.396113  0.639329      0.126665
# 14     0.0     0.0            -0.400109  0.639329      0.021283
# 15     0.0     0.0             2.530987  0.639329      0.477940
# 16     0.0     1.0            -0.381909 -1.564141      0.196920
# 17     0.0     0.0            -0.397865  0.639329      0.899469
# 18     0.0     0.0            -0.395744  0.639329      0.794087
# 19     0.0     0.0            -0.394816  0.639329      0.126665
#
#     Annual Income  Monthly Income  Credit Ration per Year  \
# 13                             0.460550
# 14                             0.020640
# 15                            -2.281028
# 16                            -0.381643
# 17                             0.266700
# 18                             0.141597
# 19                             0.171761
#
#     Current Credit Balance Credit Ration per Year  \
# 0                                       -0.012234
# 1                                        0.132843
# 2                                        0.426673
# 3                                        0.332632
# 4                                        0.427143
# 5                                        0.336506
# 6                                       -0.752861
# 7                                        0.438846
# 8                                       -0.526104
# 9                                        0.080539
# 10                                      -2.097743
# 11                                      -0.173141
# 12                                      -0.663438
# 13                                       0.342002
# 14                                       0.469095
# 15                                      -1.717111
# 16                                       0.090458
# 17                                       0.134779
# 18                                      -0.148150
# 19                                       0.283700
#
#     Monthly Income Credit Ration per Year  Credit Ration per Year^2  \
# 0                                0.317088                 -0.202003
# 1                                0.136567                 -0.201523
# 2                                0.463975                 -0.202012
# 3                               -0.024642                 -0.201642
# 4                                0.197532                 -0.203307
# 5                                0.513603                 -0.203282
# 6                                0.574209                  0.181397
# 7                                0.118669                 -0.201433
# 8                               -0.956155                 -0.201050
# 9                                0.479814                 -0.203420
# 10                              -4.353458                  3.773210
# 11                              -0.144034                 -0.201904
# 12                              -0.049992                 -0.200817
# 13                               0.170429                 -0.201747
# 14                               0.079128                 -0.201130
# 15                              -0.923509                  1.163020
# 16                              -0.381763                 -0.202077
# 17                               0.359401                 -0.201762
# 18                               0.117075                 -0.201635
# 19                               0.308588                 -0.202077
#
#     Home Ownership_Home Mortgage^2  Home Ownership_Rent^2
# 0                        -0.966542              -0.803981
# 1                        -0.966542              -0.803981
# 2                         1.034616               1.243810
# 3                         1.034616               1.243810
# 4                        -0.966542              -0.803981
# 5                         1.034616               1.243810
# 6                        -0.966542              -0.803981
# 7                        -0.966542              -0.803981
# 8                        -0.966542              -0.803981
# 9                         1.034616              -0.803981
# 10                        1.034616               1.243810
# 11                       -0.966542              -0.803981
# 12                       -0.966542              -0.803981
# 13                       -0.966542              -0.803981
# 14                        1.034616               1.243810
# 15                       -0.966542              -0.803981
# 16                       -0.966542              -0.803981
# 17                       -0.966542              -0.803981
# 18                       -0.966542              -0.803981
# 19                       -0.966542              -0.803981
#
# [20 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
cm_basic = confusion_matrix(y_test, y_pred_basic)
cm_outliers = confusion_matrix(y_test_outliers, y_pred_outliers)
cm_PCA = confusion_matrix(y_test, y_pred_PCA)
cm_FT = confusion_matrix(y_test, y_pred_FT)
cm_poly = confusion_matrix(y_test, y_pred_poly)


np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cm_basic, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
plt.figure()
plot_confusion_matrix(cm_outliers, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
plt.figure()
plot_confusion_matrix(cm_PCA, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
plt.figure()
plot_confusion_matrix(cm_FT, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
plt.figure()
plot_confusion_matrix(cm_poly, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
# Out:
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization
# Confusion matrix, without normalization

# %%
# imports 
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import cross_val_score,  StratifiedKFold
import numpy as np

# %%
# param values
alphas = np.array([0.01,0.02])
gnb_fit_prior = [True, False],

# %%
# creating  grid instance
grid_params_nn = dict(alpha=alphas, fit_prior=gnb_fit_prior)

# %%
grid_params_nn = {
  'alpha': np.linspace(0.0, 1.5, 20),
  'fit_prior': [True, False],
}

# %%
# creating KNN instance
bnb = BernoulliNB()

# %%
# search optimal params using RandomizedSearchCV
neigh_ins = RandomizedSearchCV(bnb, grid_params_nn, cv=10, scoring='f1', n_iter=700, verbose=10, n_jobs=-1)

# %%
# load data
# get data
X, y = functions.get_data(type="__PCA")
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=10, stratify=y)

# %%
# fit search
neigh_ins.fit(X_train, y_train.values.ravel())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:271: UserWarning: The total space of parameters 40 is smaller than n_iter=700. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1835s.) Setting batch_size=2.
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed:   12.9s finished
# RandomizedSearchCV(cv=10, error_score='raise-deprecating',
#           estimator=BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True),
#           fit_params=None, iid='warn', n_iter=700, n_jobs=-1,
#           param_distributions={'alpha': array([0.     , 0.07895, 0.15789, 0.23684, 0.31579, 0.39474, 0.47368,
#        0.55263, 0.63158, 0.71053, 0.78947, 0.86842, 0.94737, 1.02632,
#        1.10526, 1.18421, 1.26316, 1.34211, 1.42105, 1.5    ]), 'fit_prior': [True, False]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring='f1', verbose=10)

# %%
# get results
best_score = neigh_ins.best_score_

best_estimator = neigh_ins.best_estimator_

best_params = neigh_ins.best_params_

# %%
# write results to file
print("Best score: {0}".format(best_score))
print("Best params: {0}".format(best_params))

f = open("../results/files/bnb_tuning_results__PCA.txt", "w+")

f.write("Best score = {0} \n".format(best_score))
f.write("Best params = {0} \n".format(best_params))

f.close()
# Out:
# Best score: 0.8668420877895975
# Best params: {'fit_prior': True, 'alpha': 0.9473684210526315}

# %%
bnb = BernoulliNB(alpha=0.9473684210526315, binarize=0.0, class_prior=None, fit_prior=True)
bnb.fit(X_train, y_train.values.ravel())
# Out:
# BernoulliNB(alpha=0.9473684210526315, binarize=0.0, class_prior=None,
#       fit_prior=True)

# %%
y_pred_PCA = bnb.predict(X_test)

# %%
# calculate F1 score
f1_PCA = f1_score(y_test, y_pred_PCA)
"F1 score is = {0}".format(f1_PCA)
# Out:
# 'F1 score is = 0.8794612794612795'

# %%
f = open("../results/files/bnb_results_final.txt", "w+")
f.write("Basic BNB with PCA features: F1 score = {0} \n".format(f1_PCA))
f.close()

# %%
# write all data to CSV file for output
result = pd.DataFrame(y_pred_PCA, columns=["y_pred"])
result['y_test'] = y_test["Loan Status"].values
result.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True
# 16 -0.387466  0.643849  0.369800  ... -0.267364 -0.039760  0.395350  0.140844
# 17 -1.059968  1.931860 -0.146744  ... -0.214137  0.314972  0.085947  0.072080
# 18 -0.856731  0.147979  0.015140  ... -0.261947  0.189067  0.067537  0.055177
# 19 -0.206713  0.429867 -0.087253  ... -0.124075  0.182692  0.025882 -0.012205
#
#           20        21        22        23        24        25
# 0   0.059156 -0.031446 -0.019454 -0.066093  0.051100 -0.000903
# 1  -0.092979 -0.109952  0.050968  0.022644  0.024899  0.061057
# 2  -0.014457 -0.027887 -0.074415 -0.124431 -0.043032  0.000129
# 3   0.008497  0.019301 -0.054198 -0.201127 -0.005035  0.069333
# 4  -0.577811 -0.660793 -0.241396 -0.074608 -0.119823  0.119431
# 5  -0.052825 -0.022478 -0.075731 -0.015372 -0.043908 -0.014156
# 6   0.049238 -0.065990 -0.055590  0.057247  0.016916 -0.029343
# 7  -0.558068 -0.636538 -0.270063 -0.033699 -0.164098  0.023064
# 8  -0.126551 -0.031899  0.105481  0.069157  0.019873  0.096250
# 9  -0.052315 -0.057815 -0.021426 -0.057958 -0.089168 -0.030953
# 10 -0.050984 -0.062488 -0.059299 -0.046506 -0.105881  0.023408
# 11  0.013204 -0.032450 -0.014355  0.005483  0.051379 -0.006709
# 12  0.022362  0.019321 -0.049802  0.126415  0.045365 -0.079661
# 13 -2.633949 -0.081642 -0.573604 -0.066180 -0.329405  0.075625
# 14  1.830239 -0.059617  1.285496  0.296179  7.300727  5.968778
# 15 -0.020271  4.200906  0.277310 -0.085962  0.000802 -0.049772
# 16 -0.016114  0.000973  0.050391 -0.016823  0.066703  0.058226
# 17  0.020554 -0.057560 -0.009354 -0.037434  0.027565 -0.035621
# 18  0.004059 -0.045088 -0.029275  0.017178  0.041581 -0.040758
# 19 -0.018519 -0.076365  0.012075  0.005103  0.023013  0.021117
#
# [20 rows x 28 columns]

# %%
cm_final = confusion_matrix(y_test, y_pred_PCA)

np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cm_final, classes=['0','1'],
                      title='Confusion matrix, basic')
plt.show()
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

recall_score = recall_score(y_test, y_pred_PCA, average='weighted')
precision_score = precision_score(y_test, y_pred_PCA, average='weighted')
average_precision = average_precision_score(y_test, y_pred_PCA)

print('Average recall score: {0:0.2f}'.format(
      recall_score))
print('Average precision score: {0:0.2f}'.format(
      precision_score))
print('Average precision-recall score: {0:0.2f}'.format(
      average_precision))
# Out:
# Average recall score: 0.96
# Average precision score: 0.96
# Average precision-recall score: 0.82

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
from inspect import signature

precision, recall, _ = precision_recall_curve(y_test, y_pred_PCA)

# In matplotlib < 1.5, plt.fill_between does not have a 'step' argument
step_kwargs = ({'step': 'post'}
               if 'step' in signature(plt.fill_between).parameters
               else {})
plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall curve: AP=0.82')

# %%
# Out:
# array([1. , 0.8])
